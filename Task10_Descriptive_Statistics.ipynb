# %% [markdown]
# <a href="https://colab.research.google.com/github/CodeWithSridhar/Innomatics-Internship/blob/main/Task10_Descriptive_Statistics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Assignment**
# # Data Analysis
# # Task 10 - Descriptive Statistics

# %% [markdown]
# ## Descriptive Statistics and Python Implementation😧

# %% [markdown]
# Dataset: https://drive.google.com/file/d/1l040PTRmQ9fw5VULbwG-qM6P2A5xZIBQ/view

# %% [markdown]
# Write a Jupyter Notebook explaining all the Descriptive Statistics.
#
#     Mean
#     Median
#     Mode
#     Variance
#     Standard Deviation
#     Correlation
#     Normal Distribution (use references)
#     Feature of Normal Distribution
#     Positively Skewed & Negatively Skewed Normal Distribution
#     Effect on Mean, Median and Mode due to Skewness
#     Explain QQ Plot and show the implementation of the same
#     Explain Box Cox and show the implementation of the same
#
#
# Explain each topic (mentioned above) with the help of images, code examples (with and without library functions) and formulas (written using LaTeX

# %%
# importing libraries

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %%
# importing dataset

data = pd.read_csv("https://raw.githubusercontent.com/CodeWithSridhar/Innomatics-Internship/main/data.csv")

# %%
data.head()
# Out:
#    Mthly_HH_Income  ...  No_of_Earning_Members
# 0             5000  ...                      1
# 1             6000  ...                      1
# 2            10000  ...                      1
# 3            10000  ...                      1
# 4            12500  ...                      1
#
# [5 rows x 7 columns]

# %%
data.tail()
# Out:
#     Mthly_HH_Income  ...  No_of_Earning_Members
# 45            90000  ...                      3
# 46            98000  ...                      2
# 47           100000  ...                      3
# 48           100000  ...                      2
# 49           100000  ...                      1
#
# [5 rows x 7 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Mthly_HH_Income           50 non-null     int64
#  1   Mthly_HH_Expense          50 non-null     int64
#  2   No_of_Fly_Members         50 non-null     int64
#  3   Emi_or_Rent_Amt           50 non-null     int64
#  4   Annual_HH_Income          50 non-null     int64
#  5   Highest_Qualified_Member  50 non-null     object
#  6   No_of_Earning_Members     50 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 2.9+ KB

# %%
data.describe()
# Out:
#        Mthly_HH_Income  ...  No_of_Earning_Members
# count        50.000000  ...              50.000000
# mean      41558.000000  ...               1.460000
# std       26097.908979  ...               0.734291
# min        5000.000000  ...               1.000000
# 25%       23550.000000  ...               1.000000
# 50%       35000.000000  ...               1.000000
# 75%       50375.000000  ...               2.000000
# max      100000.000000  ...               4.000000
#
# [8 rows x 6 columns]

# %%
data.shape
# Out:
# (50, 7)

# %%
Mthly_HH_Income = data['Mthly_HH_Income'].values
print ('Maximum Monthly HH Income: ', Mthly_HH_Income.max())
print ('Minimum Monthly HH Income: ', Mthly_HH_Income.min())
print ('Average Monthly HH Income: ', Mthly_HH_Income.mean())
# Out:
# Maximum Monthly HH Income:  100000
# Minimum Monthly HH Income:  5000
# Average Monthly HH Income:  41558.0

# %%
print ('Standard Deviation: ', Mthly_HH_Income.std())
print ('Variance: ', Mthly_HH_Income.var())
print ('Median: ', np.median(Mthly_HH_Income))
print ('Mode: ', stats.mode(Mthly_HH_Income))
# Out:
# Standard Deviation:  25835.611779092826
# Variance:  667478836.0
# Median:  35000.0
# Mode:  ModeResult(mode=array([45000]), count=array([4]))

# %% [markdown]
# Checking Correlation

# %%
data.corr()
# Out:
#                        Mthly_HH_Income  ...  No_of_Earning_Members
# Mthly_HH_Income               1.000000  ...               0.347883
# Mthly_HH_Expense              0.649215  ...               0.311915
# No_of_Fly_Members             0.448317  ...               0.597482
# Emi_or_Rent_Amt               0.036976  ...              -0.097431
# Annual_HH_Income              0.970315  ...               0.296679
# No_of_Earning_Members         0.347883  ...               1.000000
#
# [6 rows x 6 columns]

# %% [markdown]
# ## Plotting Pairpolt

# %%
sns.pairplot(data)
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
Encoder = LabelEncoder()
Highest_Qualified_Member = Encoder.fit_transform(data['Highest_Qualified_Member'])
data['Highest_Qualified_Member'] = Highest_Qualified_Member
data.head(10)
# Out:
#    Mthly_HH_Income  ...  No_of_Earning_Members
# 0             5000  ...                      1
# 1             6000  ...                      1
# 2            10000  ...                      1
# 3            10000  ...                      1
# 4            12500  ...                      1
# 5            14000  ...                      1
# 6            15000  ...                      1
# 7            18000  ...                      1
# 8            19000  ...                      1
# 9            20000  ...                      2
#
# [10 rows x 7 columns]

# %% [markdown]
# ## Plotting Heatmap:

# %%
# fig, ax = plt.subplots(figsize=(20,8))
sns.heatmap(data)
# plt.xlabel('Attributes')
plt.show()

# %% [markdown]
# ## Plotting Regression Plot to obtain best fit line

# %%
fig, ax = plt.subplots(figsize=(10,6))
sns.regplot(x = data["Mthly_HH_Income"], y = data["Mthly_HH_Expense"], color="g")

# %%
fig, ax = plt.subplots(figsize=(10,6))
sns.regplot(x = data["Mthly_HH_Income"], y = data["Emi_or_Rent_Amt"], color="g")

# %%
fig, ax = plt.subplots(figsize=(10,6))
sns.regplot(x = data["Mthly_HH_Income"], y = data["No_of_Fly_Members"], color="g")

# %%
fig, ax = plt.subplots(figsize=(10,6))
sns.regplot(x = data["Mthly_HH_Income"], y = data["No_of_Earning_Members"], color="g")

# %%
fig, ax = plt.subplots(figsize=(10,6))
sns.regplot(x = data["Mthly_HH_Income"], y = data["Annual_HH_Income"], color="g")

# %%
fig, ax = plt.subplots(figsize=(10,6))
sns.regplot(x = data["Mthly_HH_Income"], y = data["No_of_Earning_Members"], color="g")

# %%
fig, ax = plt.subplots(figsize=(10,6))
sns.kdeplot(x = data["Mthly_HH_Income"], y = data["Mthly_HH_Expense"], color="g")

# %%
fig, ax = plt.subplots(figsize=(15,8))
x = data["Mthly_HH_Income"]
y = data["Mthly_HH_Expense"]
z = data["No_of_Fly_Members"]
plt.figure
plt.subplot(121)
plt.plot(x, y, color = 'green', marker = '*', linestyle = 'dashed')

plt.subplot(122)
plt.plot(x, z, color = 'green', marker = '*', linestyle = 'dashed')
plt.show()

# %% [markdown]
# ## **QQ- Plots**

# %% [markdown]
# A q-q plot is a plot of the quantiles of the first data set against the quantiles of the second data set.

# %% [markdown]
# **Mthly_HH_Income**

# %%
fig, ax = plt.subplots(figsize=(10,6))
Mthly_HH_Income = data.Mthly_HH_Income
sns.distplot(Mthly_HH_Income)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
from scipy.stats import probplot
import pylab

# %%
fig, ax = plt.subplots(figsize=(10,6))
A = probplot(Mthly_HH_Income,dist='norm',plot=pylab)
pylab.show(A)

# %% [markdown]
# **Mthly_HH_Expense**

# %%
Mthly_HH_Expense = data.Mthly_HH_Expense
fig, ax = plt.subplots(figsize=(10,6))
sns.distplot(Mthly_HH_Expense)
B = probplot(Mthly_HH_Expense,dist='norm',plot=pylab)
pylab.show(B)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# **No_of_Fly_Members**

# %%
No_of_Fly_Members = data.No_of_Fly_Members
fig, ax = plt.subplots(figsize=(10,6))
sns.distplot(No_of_Fly_Members)
C = probplot(No_of_Fly_Members,dist='norm',plot=pylab)
pylab.show(C)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# **Emi_or_Rent_Amt**

# %%
Emi_or_Rent_Amt = data.Emi_or_Rent_Amt
fig, ax = plt.subplots(figsize=(10,6))
sns.distplot(Emi_or_Rent_Amt)
D = probplot(Emi_or_Rent_Amt,dist='norm',plot=pylab)
pylab.show(D)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# **Annual_HH_Income**

# %%
Annual_HH_Income = data.Annual_HH_Income
fig, ax = plt.subplots(figsize=(10,6))
sns.distplot(Annual_HH_Income)
E = probplot(Annual_HH_Income,dist='norm',plot=pylab)
pylab.show(E)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# **Highest_Qualified_Member**

# %%
Highest_Qualified_Member = data.Highest_Qualified_Member
fig, ax = plt.subplots(figsize=(10,6))
sns.distplot(Highest_Qualified_Member)
F = probplot(Highest_Qualified_Member,dist='norm',plot=pylab)
pylab.show(F)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
No_of_Earning_Members = data.No_of_Earning_Members
fig, ax = plt.subplots(figsize=(10,6))
sns.distplot(No_of_Earning_Members)
G = probplot(No_of_Earning_Members , dist = 'norm' , plot = pylab)
pylab.show(G)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
